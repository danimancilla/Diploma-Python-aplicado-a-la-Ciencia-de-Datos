# %% [markdown]
# ![Google Drive Image](https://drive.google.com/uc?export=view&id=1zLi1EkeMV8U5nADzIndtPJj041F51g0y)

# %% [markdown]
# <h1><center>Control 1: Pandas 📷</center></h1>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesor de Catedra: [Pablo Badilla](https://github.com/pbadillatorrealba/)
# - Profesor Practico  : [Gabriel Iturra-Bocaz](https://giturra.cl/)

# %% [markdown]
# ### Integrantes
#
# - Nombre alumna: Daniela Mancilla

# %% [markdown]
# ### Reglas:
#
# - **Grupos de 2 personas**.
# - **Ausentes** deberán realizar la actividad solos.
# - Esta prohibido compartir las respuestas con otros grupos.
# - Indicios de copia serán penalizados con la nota mínima.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente, si utiliza material extra debe citarlo.
# - Por favor, que sólo suba el control una persona por grupo.

# %% [markdown]
# # Problemas

# %% [markdown]
# ### 1.- Carga y tareas exploratorias 💻

# %% [markdown]
# 1.- Cargue el archivo `online_retail_II.pickle` utilizando pandas y visualice las primeras 5 filas.

# %%
import pandas as pd
df=pd.read_pickle("online_retail_II.pickle")
df.head(5)
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# 2.- Describa brevemente de que trata el dataset cargado a partir de el nombre de las columnas y su contenido (utilice las 5 filas impresas en la pregunta anterior). ¿Qué contiene cada fila?

# %% [markdown]
# ```
# El dataset muestra compras de distintos productos, donde cada fila es un producto.
# Algunos de los atributos son: el cliente, la cantidad y el precio.
#
# El invoice correspondería al nombre de la boleta, por lo tanto,
# las primeras 5 columnas pertenecen a la misma compra.
# ```

# %% [markdown]
# 3.- Realice un análisis descriptivo básico de los datos cargadas. Para esto, escriba un código que imprima los siguientes valores:
#
# - Número de filas y columnas.
# - Nombres de las filas y columnas.

# %%
print(f"El número de filas es {df.shape[0]} y el número de columnas es {df.shape[1]}.")
# Out:
# El número de filas es 525461 y el número de columnas es 8.

# %%
print(f"Los nombres de las filas son: {df.index}")
# Out:
# Los nombres de las filas son: RangeIndex(start=0, stop=525461, step=1)

# %% [markdown]
# Las filas son números enteros que parten en 0 y finalizan en 525460, y se van saltando de a 1. Son: 0,1,2...,525459, 525460

# %%
print(f"Los nombres de las columnas son: {list(df.columns)}")
# Out:
# Los nombres de las columnas son: ['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'Price', 'Customer ID', 'Country']

# %% [markdown]
# 4.- Muestre información descriptiva (como número de valores no nulos, promedio, desviación estándar, etc...) de los valores numéricos del `Dataframe`. Asegúrese de redondear los valores para mejorar la legibilidad.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %% [markdown]
# Todos los datos son no nulos, excepto en Description y Customer ID.

# %%
df.describe().round(2)
# Out:
#         Quantity      Price  Customer ID
# count  525461.00  525461.00    417534.00
# mean       10.34       4.69     15360.65
# std       107.42     146.13      1680.81
# min     -9600.00  -53594.36     12346.00
# 25%         1.00       1.25     13983.00
# 50%         3.00       2.10     15311.00
# 75%        10.00       4.21     16799.00
# max     19152.00   25111.09     18287.00

# %% [markdown]
# 4.- Haga un conteo de el número de nulos por cada columna

# %%
df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %% [markdown]
# Como mencionamos anteriormente, sólo hay datos nulos en Description y Customer ID.

# %% [markdown]
# 5.- Descarte todos los valores nulos. Puede ayudarse para esto combinando `isna` + `any`. Investigue el método `any` previo a usarlo y vea como compatibilizarlo para este caso.

# %%
df_copia=df.copy()
no_nulos=~df_copia.isna().any(axis=1)
df_copia=df_copia.loc[no_nulos]
df_copia
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %% [markdown]
# 7. Asegure el tipo de datos de cada columna. Para esto, transforme `Invoice` a string y `Quantity` a entero y `Price` a flotante utilizando el método astype. Al igual que los casos anteriores, investigue su funcionamiento (recomendación: usar diccionarios).

# %%
df_copia=df_copia.astype({'Invoice': 'str','Quantity': 'int64','Price': 'float64'})

# %% [markdown]
# 8.- Ejecute un conteo de valores en donde se indique el número de filas que por país.

# %%
df_copia.loc[:,"Country"].value_counts()
# Out:
# United Kingdom          379423
# EIRE                      8710
# Germany                   8129
# France                    5710
# Netherlands               2769
# Spain                     1278
# Switzerland               1187
# Belgium                   1054
# Portugal                  1024
# Channel Islands            906
# Sweden                     883
# Italy                      731
# Australia                  654
# Cyprus                     554
# Austria                    537
# Greece                     517
# Denmark                    428
# Norway                     369
# Finland                    354
# United Arab Emirates       318
# Unspecified                280
# USA                        244
# Japan                      224
# Poland                     194
# Malta                      172
# Lithuania                  154
# Singapore                  117
# Canada                      77
# Thailand                    76
# Israel                      74
# ...

# %% [markdown]
# ### 2.- Duplicados 🤔
#
#
# 1. Busque la cantidad total de filas duplicadas usando la función vista en clases y apliquela sin el parámetro `subset`.

# %%
#Sin contar como duplicados la primera ocurrencia
df_copia.duplicated().sum()
# Out:
# 6771

# %%
#Contando como duplicado a la primera ocurrencia inclusive.
df_copia.duplicated(keep=False).sum()
# Out:
# 13102

# %% [markdown]
# 2. ¿Sería correcto descartar sin mayor información estas filas con valores duplicados?
#
# Para responder a esta pregunta:
#
# - Haga una inspección visual del dataframe usando el método para encontrar duplicados (instruyéndole que entregue todas las filas duplicadas, incluyendo la primera), a la vez que ordena el dataframe por las columnas `'Invoice'` y `'StockCode'` (en ese orden).
# - Reflexione acerca de como se pasan los productos en caja en un supermercado. ¿Qué sucede cuando se pasa más de un producto no consecutivo?

# %%
df_copia.loc[df_copia.duplicated(keep=False)].sort_values(by=['Invoice','StockCode']).head(10)
# Out:
#     Invoice StockCode                       Description  Quantity  \
# 379  489517     21491   SET OF THREE VINTAGE GIFT WRAPS         1
# 391  489517     21491   SET OF THREE VINTAGE GIFT WRAPS         1
# 365  489517     21821  GLITTER STAR GARLAND WITH BELLS          1
# 386  489517     21821  GLITTER STAR GARLAND WITH BELLS          1
# 363  489517     21912          VINTAGE SNAKES & LADDERS         1
# 371  489517     21912          VINTAGE SNAKES & LADDERS         1
# 394  489517     21912          VINTAGE SNAKES & LADDERS         1
# 362  489517     21913    VINTAGE SEASIDE JIGSAW PUZZLES         1
# 385  489517     21913    VINTAGE SEASIDE JIGSAW PUZZLES         1
# 368  489517     22130  PARTY CONE CHRISTMAS DECORATION          6
#
#             InvoiceDate  Price  Customer ID         Country
# 379 2009-12-01 11:34:00   1.95      16329.0  United Kingdom
# 391 2009-12-01 11:34:00   1.95      16329.0  United Kingdom
# ...

# %% [markdown]
# ```
# No es correcto descartar las filas duplicadas sin mayor información.
# Cuando se pasa más de un producto no consecutivo en el supermercado,
# en algunas ocasiones (creo que depende del supermercado) los productos quedan en distintas filas en la boleta.
# ```

# %% [markdown]
# Por último, comente pensando en un caso general, que hubiese ocurrido si se descartaban apresuradamente los datos sin comprobar que significaban los duplicados.

# %% [markdown]
# ```
# En este caso particular, hubiéramos descartado compras que sí existieron, y que no eran duplicadas, eran adicionales.
# En un caso general, al eliminar datos duplicados sin analizar el significado, se pueden perder datos imoportantes.
# ```

# %% [markdown]
# ### 3.- Creación de Columnas y Rankings 📈

# %% [markdown]
# 1.- Calcule los ingresos totales que se tienen por fila y almacenelos en una nueva columna llamada `Total`. Comente que variables son las que debe multiplicar para obtener el total por registro.

# %%
#Las variables que se deben multiplicar son el precio (Price) y la cantidad (Quantity).
df_copia["Total"]=df_copia["Price"]*df_copia["Quantity"]
df_copia
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country   Total
# ...

# %% [markdown]
# 2.- Utilizando un `.groupby()` por la columna `Description`, realice las siguientes agreaciones:
#
# - Suma, mínimo y máximo realizando una agregación sobre la columna `Total`.
# - Suma, Media, desviación estandar, mínimo y máximo realizando la agreación sobre la columna `Quantity`.
#
# Guarde los resultados en un nuevo dataframe llamado `df_summary` e imprima los resultados.

# %%
df_nuevo=df_copia.loc[:,["Description", "Quantity","Total"]].copy()
df_nuevo
# Out:
#                                 Description  Quantity   Total
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS        12   83.40
# 1                        PINK CHERRY LIGHTS        12   81.00
# 2                       WHITE CHERRY LIGHTS        12   81.00
# 3              RECORD FRAME 7" SINGLE SIZE         48  100.80
# 4            STRAWBERRY CERAMIC TRINKET BOX        24   30.00
# ...                                     ...       ...     ...
# 525456                 FELTCRAFT DOLL ROSIE         2    5.90
# 525457         FELTCRAFT PRINCESS LOLA DOLL         1    3.75
# 525458       FELTCRAFT PRINCESS OLIVIA DOLL         1    3.75
# 525459   PINK FLORAL FELTCRAFT SHOULDER BAG         2    7.50
# 525460               JUMBO STORAGE BAG SUKI         2    3.90
#
# [417534 rows x 3 columns]

# %%
df_quantity=df_nuevo.groupby('Description').agg({'Quantity':['sum','mean', 'std', 'min', 'max']}).round(2)
df_quantity
# Out:
#                                     Quantity
#                                          sum   mean    std min  max
# Description
#   DOORMAT UNION JACK GUNS AND ROSES      169   3.19   2.96   1   10
#  3 STRIPEY MICE FELTCRAFT                661   5.65   8.79  -2   80
#  4 PURPLE FLOCK DINNER CANDLES           200  11.76  14.27   1   36
#  ANIMAL STICKERS                         385  32.08  11.76  24   48
#  BLACK PIRATE TREASURE CHEST              47   3.36   2.47   1   10
# ...                                      ...    ...    ...  ..  ...
# ZINC HEART LATTICE TRAY OVAL             323  14.68  61.06  -2  288
# ZINC METAL HEART DECORATION            13891  16.68  34.78 -24  432
# ZINC POLICE BOX LANTERN                  193  48.25  92.50   1  187
# ZINC TOP  2 DOOR WOODEN SHELF            223   4.55   5.00  -4   16
# ZINC WILLIE WINKIE  CANDLE STICK        3630  13.35  14.76   1   96
#
# [4459 rows x 5 columns]

# %%
df_total=df_nuevo.groupby('Description').agg({'Total':['sum', 'min', 'max']}).round(2)
df_total
# Out:
#                                         Total
#                                           sum    min     max
# Description
#   DOORMAT UNION JACK GUNS AND ROSES   1084.75   6.75   59.50
#  3 STRIPEY MICE FELTCRAFT             1239.15  -3.90  132.00
#  4 PURPLE FLOCK DINNER CANDLES         265.20   2.55   30.60
#  ANIMAL STICKERS                        80.85   5.04   10.08
#  BLACK PIRATE TREASURE CHEST            77.55   1.65   16.50
# ...                                       ...    ...     ...
# ZINC HEART LATTICE TRAY OVAL           352.25 -11.90  144.00
# ZINC METAL HEART DECORATION          16622.75 -30.00  457.92
# ZINC POLICE BOX LANTERN                783.70   5.95  748.00
# ZINC TOP  2 DOOR WOODEN SHELF         1203.85 -59.80   63.20
# ZINC WILLIE WINKIE  CANDLE STICK      3010.62   0.85   69.12
#
# [4459 rows x 3 columns]

# %%
df_summary = pd.concat([df_total, df_quantity], axis=1)
df_summary
# Out:
#                                         Total                Quantity         \
#                                           sum    min     max      sum   mean
# Description
#   DOORMAT UNION JACK GUNS AND ROSES   1084.75   6.75   59.50      169   3.19
#  3 STRIPEY MICE FELTCRAFT             1239.15  -3.90  132.00      661   5.65
#  4 PURPLE FLOCK DINNER CANDLES         265.20   2.55   30.60      200  11.76
#  ANIMAL STICKERS                        80.85   5.04   10.08      385  32.08
#  BLACK PIRATE TREASURE CHEST            77.55   1.65   16.50       47   3.36
# ...                                       ...    ...     ...      ...    ...
# ZINC HEART LATTICE TRAY OVAL           352.25 -11.90  144.00      323  14.68
# ZINC METAL HEART DECORATION          16622.75 -30.00  457.92    13891  16.68
# ZINC POLICE BOX LANTERN                783.70   5.95  748.00      193  48.25
# ZINC TOP  2 DOOR WOODEN SHELF         1203.85 -59.80   63.20      223   4.55
# ...

# %% [markdown]
# 3.- Interprete cada una de las columnas obtenidas desde la agregación, señalando de forma breve que representan los valores obtenidos.

# %% [markdown]
# `Para Total, sum indica todo el ingreso asociado al producto (todas las compras, cuanto se recaudó), min indica el ingreso mínimo asociado al producto (una compra en particular), y max indica el ingreso máximo asociado al producto (una compra en particular).
# Para Quantity, sum indica la cantidad de productos vendidos, asociado a todas las compras.
# min indica la mínima cantidad vendida y max indica la máxima cantidad vendida. mean es el promedio de productos vendidos en cada compra y std la desviación estándar de la cantidad de productos vendidos.`

# %% [markdown]
# 4.- Utilizando `df_summary` obtenga el top 10 productos más comprados (producto con más número de ventas) y el top 10 productos que generan más ingresos (producto que deja más dinero a la tienda) en la tienda de retail. Imprima cada uno de los top señalando solo el producto y el dato pertinente al ranking solamente.
#
# - ¿Son acaso los mismos productos para ambos rankings?

# %%
#Top 10 más comprados
df_summary.sort_values(('Quantity',  'sum'), ascending=False).head(10).loc[:,('Quantity',  'sum')]
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    55861
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     54274
# BROCADE RING PURSE                    47430
# PACK OF 72 RETRO SPOT CAKE CASES      44507
# ASSORTED COLOUR BIRD ORNAMENT         44120
# 60 TEATIME FAIRY CAKE CASES           35630
# PACK OF 60 PINK PAISLEY CAKE CASES    30888
# JUMBO BAG RED RETROSPOT               29498
# BLACK AND WHITE PAISLEY FLOWER MUG    25679
# SMALL POPCORN HOLDER                  25394
# Name: (Quantity, sum), dtype: int64

# %%
#Top 10 más ingresos
df_summary.sort_values(('Total',  'sum'), ascending=False).head(10).loc[:,('Total',  'sum')]
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER     148876.66
# REGENCY CAKESTAND 3 TIER               136866.30
# ASSORTED COLOUR BIRD ORNAMENT           69854.96
# JUMBO BAG RED RETROSPOT                 51608.40
# POSTAGE                                 45520.86
# ROTATING SILVER ANGELS T-LIGHT HLDR     39902.10
# PAPER CHAIN KIT 50'S CHRISTMAS          36866.45
# PARTY BUNTING                           34998.70
# JUMBO BAG STRAWBERRY                    33893.70
# VINTAGE UNION JACK BUNTING              33546.96
# Name: (Total, sum), dtype: float64

# %% [markdown]
# `Algunos productos aparecen en ambos ránkings, pero claramente no son los mismos. El top 1 sí coincide.`

# %% [markdown]
# 4.- En base a `df_summary` genere los quintiles `["Muy bajo", "Bajo", "Medio", "Medio alto", "Alto"]` sobre la columna `('Total', 'sum')`.

# %%
df_summary["Quintiles"]=pd.qcut(df_summary[('Total',  'sum')],q=5,labels = ["Muy bajo", "Bajo", "Medio", "Medio alto", "Alto"])

# %%
df_summary
# Out:
#                                         Total                Quantity         \
#                                           sum    min     max      sum   mean
# Description
#   DOORMAT UNION JACK GUNS AND ROSES   1084.75   6.75   59.50      169   3.19
#  3 STRIPEY MICE FELTCRAFT             1239.15  -3.90  132.00      661   5.65
#  4 PURPLE FLOCK DINNER CANDLES         265.20   2.55   30.60      200  11.76
#  ANIMAL STICKERS                        80.85   5.04   10.08      385  32.08
#  BLACK PIRATE TREASURE CHEST            77.55   1.65   16.50       47   3.36
# ...                                       ...    ...     ...      ...    ...
# ZINC HEART LATTICE TRAY OVAL           352.25 -11.90  144.00      323  14.68
# ZINC METAL HEART DECORATION          16622.75 -30.00  457.92    13891  16.68
# ZINC POLICE BOX LANTERN                783.70   5.95  748.00      193  48.25
# ZINC TOP  2 DOOR WOODEN SHELF         1203.85 -59.80   63.20      223   4.55
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=87110296-876e-426f-b91d-aaf681223468' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
